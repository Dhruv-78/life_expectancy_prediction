# %% [markdown]
# ### Importing Modules and Data

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("Life_Expectancy_Data.csv")
data.head()
# Out:
#        Country  Year      Status  Life_expectancy   Adult_Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total_expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# ### Knowing the data

# %%
data.shape
# Out:
# (2938, 22)

# %%
data.describe()
# Out:
#               Year  Life_expectancy   Adult_Mortality  infant_deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage_expenditure  Hepatitis_B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life_expectancy                  2928 non-null   float64
#  4   Adult_Mortality                  2928 non-null   float64
#  5   infant_deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage_expenditure           2938 non-null   float64
#  8   Hepatitis_B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five_deaths                2938 non-null   int64
# ...

# %%
data = data.dropna()

# %%
data['Status'].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
data['Country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bangladesh',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Costa Rica', 'Croatia', 'Cyprus',
#        'Djibouti', 'Dominican Republic', 'Ecuador', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Estonia', 'Ethiopia', 'Fiji',
#        'France', 'Gabon', 'Georgia', 'Germany', 'Ghana', 'Greece',
#        'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Honduras', 'India', 'Indonesia', 'Iraq', 'Ireland', 'Israel',
#        'Italy', 'Jamaica', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Lithuania',
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder() 
data['Status'] = le.fit_transform(data['Status'])
data['Country']=le.fit_transform(data['Country'])
data.head()
# Out:
#    Country  Year  Status  Life_expectancy   Adult_Mortality  infant_deaths  \
# 0        0  2015       1              65.0            263.0             62
# 1        0  2014       1              59.9            271.0             64
# 2        0  2013       1              59.9            268.0             66
# 3        0  2012       1              59.5            272.0             69
# 4        0  2011       1              59.2            275.0             71
#
#    Alcohol  percentage_expenditure  Hepatitis_B  Measles   ...  Polio  \
# 0     0.01               71.279624         65.0      1154  ...    6.0
# 1     0.01               73.523582         62.0       492  ...   58.0
# 2     0.01               73.219243         64.0       430  ...   62.0
# 3     0.01               78.184215         67.0      2787  ...   67.0
# 4     0.01                7.097109         68.0      3013  ...   68.0
#
#    Total_expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# ## Indentifying columns with high corelation

# %%
corr = data.corr()

# %%
cols = corr.columns.to_list()
ind = corr.index.to_list()

# %%
for i in range(len(cols)):
    for j in range(i+1,len(ind)):
        if abs(corr[cols[i]][ind[j]]) >= 0.8:
            print(cols[i]+" "+ind[j]+" "+":"+str(corr[cols[i]][ind[j]]))
# Out:
# infant_deaths under-five_deaths  :0.9969056219353224
# percentage_expenditure GDP :0.9592988569672184
#  thinness (1-19 years)  thinness(5-9 years) :0.9279134442386393

# %% [markdown]
# ## So we can delete  - infant_deaths , percentage_expenditure ,   thinness(5-9 years)

# %%
data = data.drop('infant_deaths',axis=1)

# %%
data=data.drop('percentage_expenditure',axis=1)

# %%
data=data.drop(' thinness(5-9 years)',axis=1)

# %%
data.head()
# Out:
#    Country  Year  Status  Life_expectancy   Adult_Mortality  Alcohol  \
# 0        0  2015       1              65.0            263.0     0.01
# 1        0  2014       1              59.9            271.0     0.01
# 2        0  2013       1              59.9            268.0     0.01
# 3        0  2012       1              59.5            272.0     0.01
# 4        0  2011       1              59.2            275.0     0.01
#
#    Hepatitis_B  Measles    BMI   under-five_deaths   Polio  Total_expenditure  \
# 0         65.0      1154   19.1                  83    6.0               8.16
# 1         62.0       492   18.6                  86   58.0               8.18
# 2         64.0       430   18.1                  89   62.0               8.13
# 3         67.0      2787   17.6                  93   67.0               8.52
# 4         68.0      3013   17.2                  97   68.0               7.87
#
#    Diphtheria    HIV/AIDS         GDP  Population   thinness (1-19 years)  \
# ...

# %%
data.shape
# Out:
# (1649, 19)

# %% [markdown]
# ## Plotting the data against life expectancy

# %%
cols = data.columns.to_list()
cols.remove('Year')
cols.remove("Life_expectancy ")
cols.remove('Country')
cols.remove('Status')
for column in cols:
    plt.figure(figsize=(5, 4))
    plt.scatter(data[column],data['Life_expectancy '])
    plt.title(f'Plot of {column} Vs Life Expectancy')
    plt.xlabel(column)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %% [markdown]
# ## Now plotting life expectancy for categorical columns

# %%
plt.figure(figsize=(6, 4))
color_code= ['red' if is_true else 'blue' for is_true in data['Status']]
plt.scatter(data.index, data['Life_expectancy '], marker='o',color=color_code)
plt.title('Red - Developing  | Blue - Developed')
plt.xlabel('Index')
plt.ylabel('Life Expectancy')
plt.show()

# %%
color_code= []
for i in data['Year']:
    if 2000<=i<2005:
        color_code.append('blue')
    elif 2005<=i<2010:
        color_code.append('green')
    elif 2010<=i<=2015:
        color_code.append('orange')
plt.scatter(data.index, data['Life_expectancy '], marker='o',color=color_code)
plt.title('Blue - Year 2000-2004 | Green - Year 2005-2009 | Orange - 2010-2015')
plt.xlabel('Index')
plt.ylabel('charges')
plt.show()

# %% [markdown]
# ## So we can drop year , country

# %%
data = data.drop('Year',axis=1)
data = data.drop('Country',axis=1)

# %%
data.shape
# Out:
# (1649, 17)

# %%
y = data["Life_expectancy "]
x = data.drop('Life_expectancy ',axis=1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_scaled= scaler.fit_transform(x)

print(x_scaled)
# Out:
# [[ 0.4147254   0.75662881 -1.12294757 ...  2.68590913 -0.83346213
#   -0.72279909]
#  [ 0.4147254   0.82048963 -1.12294757 ...  2.75115725 -0.8498526
#   -0.75858316]
#  [ 0.4147254   0.79654182 -1.12294757 ...  2.79465599 -0.88263354
#   -0.79436723]
#  ...
#  [ 0.4147254  -0.76006583 -0.02561984 ... -0.79399062 -1.11756359
#   -0.75858316]
#  [ 0.4147254   4.13327002 -0.6984158  ... -0.70699312 -1.11756359
#   -0.8301513 ]
#  [ 0.4147254   3.96563535 -0.70834637 ...  1.33744798 -1.07931916
#   -0.8301513 ]]

# %% [markdown]
# ## Trying PCA and BERUTA for further Pre-processing

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)

r2_scores = []

num_features = X_train.shape[1]
components_range = range(1, num_features + 1)

for n_components in components_range:
    pca = PCA(n_components=n_components)
    X_train_pca = pca.fit_transform(X_train)
    X_test_pca = pca.transform(X_test)

    regressor = RandomForestRegressor(random_state=42)
    regressor.fit(X_train_pca, y_train)

    y_pred = regressor.predict(X_test_pca)

    r2 = r2_score(y_test, y_pred)
    r2_scores.append(r2)

plt.figure(figsize=(8, 6))
plt.plot(components_range, r2_scores, marker='o', linestyle='--', color='b')
plt.title("R² Score vs Number of PCA Components")
plt.xlabel("Number of PCA Components")
plt.ylabel("R² Score")
plt.grid(alpha=0.5)
plt.show()

# %% [markdown]
# ## PCA doesn't helped much

# %%
## BERUTA
from boruta import BorutaPy

rf = RandomForestRegressor(n_jobs=-1, random_state=42)

boruta = BorutaPy(estimator=rf, n_estimators='auto', random_state=42)

boruta.fit(x_scaled, y)

# Get selected features
selected_features = x.columns[boruta.support_]
print("\nSelected features by Boruta:")
print(selected_features)
# Out:
# Selected features by Boruta:
# Index(['Adult_Mortality', 'Alcohol', 'Measles ', ' BMI ', 'under-five_deaths ',
#        'Polio', 'Total_expenditure', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness (1-19 years)', 'Income_composition_of_resources',
#        'Schooling'],
#       dtype='object')

# %%
X_train = pd.DataFrame(X_train, columns=x.columns)
X_test = pd.DataFrame(X_test, columns=x.columns)

X_train_selected = X_train[['Adult_Mortality', 'Alcohol', 'Measles ', ' BMI ', 'under-five_deaths ',
       'Polio', 'Total_expenditure', ' HIV/AIDS', 'GDP', 'Population',
       ' thinness (1-19 years)', 'Income_composition_of_resources',
       'Schooling']]
X_test_selected = X_test[['Adult_Mortality', 'Alcohol', 'Measles ', ' BMI ', 'under-five_deaths ',
       'Polio', 'Total_expenditure', ' HIV/AIDS', 'GDP', 'Population',
       ' thinness (1-19 years)', 'Income_composition_of_resources',
       'Schooling']]

regressor = RandomForestRegressor(random_state=42)
regressor.fit(X_train_selected, y_train)

y_pred = regressor.predict(X_test_selected)

print(r2_score(y_test, y_pred))
# Out:
# 0.9482203333269479

# %% [markdown]
# # Model selection

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression,Ridge,PoissonRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

test_model = [LinearRegression(),Ridge(alpha=1.0),PoissonRegressor(), 
              DecisionTreeRegressor(max_depth=5),RandomForestRegressor(n_estimators=100),SVR(kernel='linear')]
model = ['Linear Regression','Ridge','Poisson Regressor','Decision tree regressor',
         'Random Forest Regressor','Support Vector Regression']
result = pd.DataFrame(columns=['Model','RMSE','r2_score'])
for i, j in enumerate(test_model):
    train_model = j.fit(X_train_selected,y_train)
    y_pred = j.predict(X_test_selected)
    r2 = r2_score(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    results = pd.DataFrame({'Model':[model[i]],'RMSE':[rmse],'r2_score':[r2]})
    result = pd.concat([result,results],ignore_index = True)
result
# Out:
#                        Model      RMSE  r2_score
# 0          Linear Regression  3.735807  0.803495
# 1                      Ridge  3.735583  0.803519
# 2          Poisson Regressor  3.651908  0.812222
# 3    Decision tree regressor  3.061449  0.868035
# 4    Random Forest Regressor  1.918333  0.948185
# 5  Support Vector Regression  3.793728  0.797355

# %% [markdown]
# ### Selected Models  - Random Forest , Decision tree

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

model = RandomForestRegressor(random_state=42)

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2']
}

grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error', verbose=1, n_jobs=-1)
grid_search.fit(X_train_selected, y_train)

best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_selected)

rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"R^2 Score: {r2:.4f}")
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# RMSE: 1.9158
# R^2 Score: 0.9483

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score

model = DecisionTreeRegressor(random_state=42)

param_grid = {
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5],
    'max_features': ['sqrt', 'log2', None]
}

grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error', verbose=1)
grid_search.fit(X_train_selected, y_train)

best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_selected)

rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"R^2 Score: {r2:.4f}")
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# RMSE: 2.8621
# R^2 Score: 0.8847

# %% [markdown]
# ## Got best results for BERUTA --> Random Forest Regressor
# ### RMSE : 1.91
# ### R2 Score : 0.95
